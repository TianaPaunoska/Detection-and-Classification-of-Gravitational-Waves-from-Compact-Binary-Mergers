# %%
import os
import numpy as np
#directory_path = '/kaggle/input/ligodata/ligodata'  
file_paths = []

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW150914_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW150914_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW151226_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW151226_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170104_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170104_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170608_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170608_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170729_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170729_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170729_V_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170809_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170809_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170814_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170814_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170817_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170818_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170823_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW170823_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190408_181802_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190408_181802_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190412_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190412_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190413_052954_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190413_134308_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190421_213856_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190425_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190425_V_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190426_190642_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190503_185404_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190503_185404_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190513_205428_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190514_065416_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190517_055101_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190517_055101_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190519_153544_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190519_153544_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190521_074359_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190521_074359_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190521_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190521_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190521_V_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190527_092055_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190602_175927_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190620_030421_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190630_185205_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190701_203306_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190701_203306_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190706_222641_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190706_222641_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190708_232457_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190719_215514_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190725_174728_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190727_060333_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190731_140936_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190803_022701_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190805_211137_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190814_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190828_063405_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190828_063405_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190910_112807_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190915_235702_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190915_235702_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190916_200658_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190917_114630_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190917_114630_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190917_114630_V_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190924_021846_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190925_232845_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190925_232845_V_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW190929_012149_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW191109_010717_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW191109_010717_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW191127_050227_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW191127_050227_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW191204_171526_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW191216_213338_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW191219_163120_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW191219_163120_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW191222_033537_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW191222_033537_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW191230_180458_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW191230_180458_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200112_155838_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200115_042309_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200115_042309_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200128_022011_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200129_065458_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200129_065458_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200208_130117_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200209_085452_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200216_220804_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200219_094415_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200220_061928_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200224_222234_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200224_222234_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200224_222234_V_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200225_060421_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200302_015811_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200311_115853_H_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200311_115853_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
for i in range (0,16):
    file_path = f"/kaggle/input/ligodata/ligodata/GW200316_215756_L_segment_{i}.npy"
    file_paths.append(file_path)

# %%
print(len(file_paths))
# Out:
# 1632

# %%
labels = np.load('/kaggle/input/ligolabels/labelsligo.npy')

# %%
file_paths = np.array(file_paths)
labels = np.array(labels)

data_array = np.core.records.fromarrays([file_paths, labels], names=['Path', 'Label'])

np.save('segmentlabels.npy', data_array)

# %%
import pandas as pd

data_array = np.load('segmentlabels.npy', allow_pickle=True)

df = pd.DataFrame(data_array)

print(df.head(32))
# Out:
#                                                  Path      Label
# 0   /kaggle/input/ligodata/ligodata/GW150914_H_seg...      Noise
# 1   /kaggle/input/ligodata/ligodata/GW150914_H_seg...      Noise
# 2   /kaggle/input/ligodata/ligodata/GW150914_H_seg...      Noise
# 3   /kaggle/input/ligodata/ligodata/GW150914_H_seg...      Noise
# 4   /kaggle/input/ligodata/ligodata/GW150914_H_seg...      Noise
# 5   /kaggle/input/ligodata/ligodata/GW150914_H_seg...  Noise+BBH
# 6   /kaggle/input/ligodata/ligodata/GW150914_H_seg...      Noise
# 7   /kaggle/input/ligodata/ligodata/GW150914_H_seg...      Noise
# 8   /kaggle/input/ligodata/ligodata/GW150914_H_seg...      Noise
# 9   /kaggle/input/ligodata/ligodata/GW150914_H_seg...      Noise
# 10  /kaggle/input/ligodata/ligodata/GW150914_H_seg...      Noise
# 11  /kaggle/input/ligodata/ligodata/GW150914_H_seg...      Noise
# 12  /kaggle/input/ligodata/ligodata/GW150914_H_seg...      Noise
# ...
